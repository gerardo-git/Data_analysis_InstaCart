# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# setting up data path as a raw string
data_path = r'C:\Users\gerar\CareerFoundry Python\Instacart Basket Analysis\02 Data'

# %% [markdown]
# ### Importing files

# %%
# importing pickle file as df_orders_products_combined
df_orders_products_combined = pd.read_pickle(os.path.join(data_path, 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_products_consistent = pd.read_csv(os.path.join(data_path, 'Prepared Data', 'products_consistent.csv'), index_col = False)

# %% [markdown]
# ### 4. Checking shape of imported files

# %%
# shape 
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
# shape
df_products_consistent.shape
# Out:
# (49672, 5)

# %% [markdown]
# ### 5. Combining data frames

# %%
# Checking keys of both dataframes
df_products_consistent.head(1)
# Out:
#    product_id                product_name  aisle_id  department_id  prices
# 0           1  Chocolate Sandwich Cookies        61             19     5.8

# %%
# the last column "_merge" is causing an error when merging, it needs to be deleted
df_orders_products_combined
# Out:
#           order_id  user_id  customer_order_count  order_day_of_the_week  \
# 0          2539329        1                     1                      2
# 1          2539329        1                     1                      2
# 2          2539329        1                     1                      2
# 3          2539329        1                     1                      2
# 4          2539329        1                     1                      2
# ...            ...      ...                   ...                    ...
# 32434484   2977660   206209                    13                      1
# 32434485   2977660   206209                    13                      1
# 32434486   2977660   206209                    13                      1
# 32434487   2977660   206209                    13                      1
# 32434488   2977660   206209                    13                      1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# getting rid of '_merge' column to avoid ValueError. 
df_orders_products_combined = df_orders_products_combined.drop('_merge', axis=1)

# %%
# merging df_products_consistent and df_orders_products_combined
df_orders_products_merge = df_products_consistent.merge(df_orders_products_combined, on = ['product_id'], indicator = True )

# %%
df_orders_products_merge
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  customer_order_count  \
# ...

# %% [markdown]
# ### 6. Confirming merge results

# %%
# value counts of merge flag
df_orders_products_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Exporting merged dataframe

# %%
df_orders_products_merge.to_pickle(os.path.join(data_path, 'Prepared Data', 'orders_products_merge.pkl'))

# %%
# checking shape of exported dataframe
df_orders_products_merge.shape
# Out:
# (32404859, 14)
